# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('candidate_variables.csv')

# %%
df.head()
# Out:
#    Recnum  Amount  Fraud  Dow_Risk  Merch state_TE  Merch zip_TE  \
# 0       1    3.62      0  0.031756        0.017176      0.020604
# 1       2   31.42      0  0.031756        0.015752      0.020604
# 2       3  178.49      0  0.031756        0.028553      0.020604
# 3       4    3.62      0  0.031756        0.017176      0.020604
# 4       5    3.62      0  0.031756        0.017176      0.020604
#
#    Cardnum_day_since  Cardnum_count_0  Cardnum_avg_0  Cardnum_max_0  ...  \
# 0             1461.0                1           3.62           3.62  ...
# 1             1461.0                1          31.42          31.42  ...
# 2             1461.0                1         178.49         178.49  ...
# 3             1461.0                1           3.62           3.62  ...
# 4                0.0                2           3.62           3.62  ...
#
#    Card_Merchnum_State_count_1_by_60_sq  Card_Merchdesc_State_count_0_by_7_sq  \
# ...
